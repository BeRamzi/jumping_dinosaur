# %%
import pandas as pd

data = pd.read_csv("output_data.csv")
data2 = pd.read_csv("output.csv")
data2
# Out:
#      x_positions  y_positions
# 0            575           90
# 1             89           90
# 2            130          106
# 3            114           90
# 4            135          106
# ..           ...          ...
# 344          109           90
# 345          162           90
# 346          167           81
# 347          225           81
# 348          212           47
#
# [349 rows x 2 columns]

# %%
import plotly.express as px
fig = px.scatter(data2,x="y_positions"  y="x_positions", title="Simple Y Graph")
fig.show()
